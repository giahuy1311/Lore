# %% [markdown]
# ### Dataset ###

# %%
from torch_geometric.datasets import TUDataset
dataset = TUDataset(root="TUDataset", name="MUTAG")

# %%
# Out:
# Data(edge_index=[2, 32], x=[16, 14], edge_attr=[32, 3], y=[1])

# %%
from sklearn.model_selection import train_test_split
from torch_geometric.data import DataLoader
labels = [data.y.item() for data in dataset]

train_idx, temp_idx = train_test_split(
    list(range(len(dataset))),
    test_size=0.2,              
    stratify=labels,
    random_state=42
)


val_idx, test_idx = train_test_split(
    temp_idx,
    test_size=0.5,              
    stratify=[labels[i] for i in temp_idx],
    random_state=42
)

train_dataset = [dataset[i] for i in train_idx]
val_dataset = [dataset[i] for i in val_idx]
test_dataset = [dataset[i] for i in test_idx]

print(f"Training set   = {len(train_dataset)} graphs")
print(f"Validation set = {len(val_dataset)} graphs")
print(f"Test set       = {len(test_dataset)} graphs")

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)
# Out:
# Training set   = 150 graphs
# Validation set = 19 graphs
# Test set       = 19 graphs
# /Users/admin/Documents/Screenshots/LORE/.env/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)

# %%
import torch
from torch import nn
from torch_geometric.nn import GCNConv, global_add_pool, GraphConv, Linear
import torch.nn.functional as F

class GCN(torch.nn.Module):
    def __init__(self, num_features, num_classes, dim):
        super(GCN, self).__init__()

        self.dim = dim
        self.num_features = num_features
        self.num_classes = num_classes

        self.conv1 = GraphConv(self.num_features, dim)
        self.conv2 = GraphConv(dim, dim)
        self.conv3 = GraphConv(dim, dim)
        # self.conv4 = GraphConv(dim, dim)
        # self.conv5 = GraphConv(dim, dim)

        self.lin1 = Linear(dim, dim)
        self.lin2 = Linear(dim, self.num_classes)

    def forward(self, x, edge_index, batch = None, edge_weight=None):
        x = self.conv1(x, edge_index, edge_weight).relu()
        x = self.conv2(x, edge_index, edge_weight).relu()
        x = self.conv3(x, edge_index, edge_weight).relu()
        # x = self.conv4(x, edge_index, edge_weight).relu()
        # x = self.conv5(x, edge_index, edge_weight).relu()
        embedding = global_add_pool(x, batch)
        x = self.lin1(embedding).relu()
        x = F.dropout(x, p=0.5, training=self.training)
        x = self.lin2(x)
        return x, embedding

    
    def predict(self, x, edge_index, batch=None):
        device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        x = x.to(device)
        edge_index = edge_index.to(device)
        if batch is not None:
          batch = batch.to(device)
        out, graph_embedding = self.forward(x, edge_index, batch)
        return out, graph_embedding

# %%
gcn = GCN(
    num_features=dataset.num_features,
    dim=32,
    num_classes=dataset.num_classes
)

optimizer = torch.optim.Adam(gcn.parameters(), lr=0.01)
criterion = torch.nn.CrossEntropyLoss()

def train(train_loader):
    gcn.train()
    for data in train_loader:
        optimizer.zero_grad()
        output, embedding = gcn(data.x, data.edge_index, data.batch)
        loss = criterion(output, data.y)
        loss.backward()
        optimizer.step()
    return loss

def test(loader):
    gcn.eval()
    correct = 0
    for data in loader:
        out, embedding = gcn(data.x, data.edge_index, data.batch)
        pred = out.argmax(dim=1)  # Predict the most probable class
        correct += int((pred == data.y).sum())
    return correct / len(loader.dataset)  # Return the accuracy

acc_plt = []
TestAcc_lst = []
loss_lst = []
epoch_lst = []
for epoch in range(500):
    train_loss = train(train_loader)
    train_acc = test(train_loader)
    test_acc = test(test_loader)
    print(f"Epoch {epoch}: Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f}, Test Acc: {test_acc:.4f}")
    acc_plt.append(train_acc)
    TestAcc_lst.append(test_acc)
    epoch_lst.append(epoch)
    loss_lst.append(train_loss)
# Out:
# Epoch 0: Train Loss: 0.6739, Train Acc: 0.7067, Test Acc: 0.7368
# Epoch 1: Train Loss: 0.4866, Train Acc: 0.6667, Test Acc: 0.6316
# Epoch 2: Train Loss: 0.9794, Train Acc: 0.6667, Test Acc: 0.6316
# Epoch 3: Train Loss: 0.5704, Train Acc: 0.6667, Test Acc: 0.6316
# Epoch 4: Train Loss: 0.6529, Train Acc: 0.6667, Test Acc: 0.6316
# Epoch 5: Train Loss: 0.6232, Train Acc: 0.6667, Test Acc: 0.6316
# Epoch 6: Train Loss: 0.5301, Train Acc: 0.7067, Test Acc: 0.6842
# Epoch 7: Train Loss: 0.5007, Train Acc: 0.7667, Test Acc: 0.7368
# Epoch 8: Train Loss: 0.4349, Train Acc: 0.7933, Test Acc: 0.6842
# Epoch 9: Train Loss: 0.5728, Train Acc: 0.8000, Test Acc: 0.6842
# Epoch 10: Train Loss: 0.7465, Train Acc: 0.8067, Test Acc: 0.6842
# Epoch 11: Train Loss: 0.4588, Train Acc: 0.8067, Test Acc: 0.6842
# Epoch 12: Train Loss: 0.5105, Train Acc: 0.8067, Test Acc: 0.6316
# Epoch 13: Train Loss: 0.2839, Train Acc: 0.8067, Test Acc: 0.6316
# Epoch 14: Train Loss: 0.2646, Train Acc: 0.8067, Test Acc: 0.6842
# Epoch 15: Train Loss: 0.4813, Train Acc: 0.8133, Test Acc: 0.6316
# Epoch 16: Train Loss: 0.3812, Train Acc: 0.8133, Test Acc: 0.6842
# Epoch 17: Train Loss: 0.4093, Train Acc: 0.8133, Test Acc: 0.6842
# Epoch 18: Train Loss: 0.5290, Train Acc: 0.8200, Test Acc: 0.6842
# Epoch 19: Train Loss: 0.5652, Train Acc: 0.8067, Test Acc: 0.6842
# Epoch 20: Train Loss: 0.3793, Train Acc: 0.7933, Test Acc: 0.6842
# Epoch 21: Train Loss: 0.5562, Train Acc: 0.8333, Test Acc: 0.5789
# Epoch 22: Train Loss: 0.5226, Train Acc: 0.8200, Test Acc: 0.7368
# Epoch 23: Train Loss: 0.4630, Train Acc: 0.8200, Test Acc: 0.7368
# Epoch 24: Train Loss: 0.4924, Train Acc: 0.8400, Test Acc: 0.6842
# Epoch 25: Train Loss: 0.3862, Train Acc: 0.8200, Test Acc: 0.6842
# Epoch 26: Train Loss: 0.3841, Train Acc: 0.8400, Test Acc: 0.6842
# Epoch 27: Train Loss: 0.4289, Train Acc: 0.8200, Test Acc: 0.7368
# Epoch 28: Train Loss: 0.3594, Train Acc: 0.8133, Test Acc: 0.7368
# Epoch 29: Train Loss: 0.3538, Train Acc: 0.8067, Test Acc: 0.6316
# Epoch 30: Train Loss: 0.4731, Train Acc: 0.8067, Test Acc: 0.6316
# Epoch 31: Train Loss: 0.4326, Train Acc: 0.8200, Test Acc: 0.7895
# Epoch 32: Train Loss: 0.2236, Train Acc: 0.8067, Test Acc: 0.6316
# Epoch 33: Train Loss: 0.3481, Train Acc: 0.8200, Test Acc: 0.7368
# Epoch 34: Train Loss: 0.4046, Train Acc: 0.8200, Test Acc: 0.5789
# Epoch 35: Train Loss: 0.3204, Train Acc: 0.8467, Test Acc: 0.6316
# Epoch 36: Train Loss: 0.3120, Train Acc: 0.8267, Test Acc: 0.7368
# Epoch 37: Train Loss: 0.3452, Train Acc: 0.8533, Test Acc: 0.6842
# Epoch 38: Train Loss: 0.3662, Train Acc: 0.8333, Test Acc: 0.7895
# Epoch 39: Train Loss: 0.2837, Train Acc: 0.8400, Test Acc: 0.6842
# Epoch 40: Train Loss: 0.2303, Train Acc: 0.8400, Test Acc: 0.7368
# Epoch 41: Train Loss: 0.4441, Train Acc: 0.8333, Test Acc: 0.7895
# Epoch 42: Train Loss: 0.4634, Train Acc: 0.8200, Test Acc: 0.7368
# Epoch 43: Train Loss: 0.4131, Train Acc: 0.8533, Test Acc: 0.7895
# Epoch 44: Train Loss: 0.3228, Train Acc: 0.8667, Test Acc: 0.7895
# Epoch 45: Train Loss: 0.4395, Train Acc: 0.8467, Test Acc: 0.7368
# Epoch 46: Train Loss: 0.3298, Train Acc: 0.8800, Test Acc: 0.8421
# Epoch 47: Train Loss: 0.5155, Train Acc: 0.8400, Test Acc: 0.7368
# Epoch 48: Train Loss: 0.5592, Train Acc: 0.8400, Test Acc: 0.7368
# Epoch 49: Train Loss: 0.4407, Train Acc: 0.7933, Test Acc: 0.7895
# Epoch 50: Train Loss: 0.3697, Train Acc: 0.8133, Test Acc: 0.7368
# Epoch 51: Train Loss: 0.3547, Train Acc: 0.8267, Test Acc: 0.7368
# Epoch 52: Train Loss: 0.5229, Train Acc: 0.8533, Test Acc: 0.7368
# Epoch 53: Train Loss: 0.3531, Train Acc: 0.8867, Test Acc: 0.7895
# Epoch 54: Train Loss: 0.2487, Train Acc: 0.8533, Test Acc: 0.7368
# Epoch 55: Train Loss: 0.1332, Train Acc: 0.8800, Test Acc: 0.7895
# Epoch 56: Train Loss: 0.2731, Train Acc: 0.8933, Test Acc: 0.7895
# Epoch 57: Train Loss: 0.2038, Train Acc: 0.8867, Test Acc: 0.7895
# Epoch 58: Train Loss: 0.4762, Train Acc: 0.9067, Test Acc: 0.8421
# Epoch 59: Train Loss: 0.4101, Train Acc: 0.8333, Test Acc: 0.7895
# Epoch 60: Train Loss: 0.4103, Train Acc: 0.8467, Test Acc: 0.6842
# Epoch 61: Train Loss: 0.3070, Train Acc: 0.8933, Test Acc: 0.7895
# Epoch 62: Train Loss: 0.1755, Train Acc: 0.9067, Test Acc: 0.7895
# Epoch 63: Train Loss: 0.3674, Train Acc: 0.9000, Test Acc: 0.7895
# Epoch 64: Train Loss: 0.2350, Train Acc: 0.9000, Test Acc: 0.7895
# Epoch 65: Train Loss: 0.1729, Train Acc: 0.9200, Test Acc: 0.8421
# Epoch 66: Train Loss: 0.3695, Train Acc: 0.8867, Test Acc: 0.8421
# Epoch 67: Train Loss: 0.2573, Train Acc: 0.9200, Test Acc: 0.8421
# Epoch 68: Train Loss: 0.3855, Train Acc: 0.9067, Test Acc: 0.8421
# Epoch 69: Train Loss: 0.2579, Train Acc: 0.9200, Test Acc: 0.7895
# Epoch 70: Train Loss: 0.2163, Train Acc: 0.9200, Test Acc: 0.8421
# Epoch 71: Train Loss: 0.1843, Train Acc: 0.9200, Test Acc: 0.7895
# Epoch 72: Train Loss: 0.3597, Train Acc: 0.9267, Test Acc: 0.8421
# Epoch 73: Train Loss: 0.2979, Train Acc: 0.9267, Test Acc: 0.8421
# Epoch 74: Train Loss: 0.1553, Train Acc: 0.9133, Test Acc: 0.8421
# Epoch 75: Train Loss: 0.3737, Train Acc: 0.9200, Test Acc: 0.7895
# Epoch 76: Train Loss: 0.1303, Train Acc: 0.9333, Test Acc: 0.8421
# Epoch 77: Train Loss: 0.3033, Train Acc: 0.9333, Test Acc: 0.7895
# Epoch 78: Train Loss: 0.2759, Train Acc: 0.9133, Test Acc: 0.7895
# Epoch 79: Train Loss: 0.3561, Train Acc: 0.9267, Test Acc: 0.8947
# Epoch 80: Train Loss: 0.2111, Train Acc: 0.9400, Test Acc: 0.8947
# Epoch 81: Train Loss: 0.2657, Train Acc: 0.9133, Test Acc: 0.7895
# Epoch 82: Train Loss: 0.2974, Train Acc: 0.9200, Test Acc: 0.8421
# Epoch 83: Train Loss: 0.1261, Train Acc: 0.9600, Test Acc: 0.8421
# Epoch 84: Train Loss: 0.2314, Train Acc: 0.9400, Test Acc: 0.8421
# Epoch 85: Train Loss: 0.0705, Train Acc: 0.8933, Test Acc: 0.8421
# Epoch 86: Train Loss: 0.3583, Train Acc: 0.9467, Test Acc: 0.8421
# Epoch 87: Train Loss: 0.1770, Train Acc: 0.9133, Test Acc: 0.7895
# Epoch 88: Train Loss: 0.3823, Train Acc: 0.9467, Test Acc: 0.9474
# Epoch 89: Train Loss: 0.4099, Train Acc: 0.8133, Test Acc: 0.8421
# Epoch 90: Train Loss: 0.2298, Train Acc: 0.9400, Test Acc: 0.9474
# Epoch 91: Train Loss: 0.1191, Train Acc: 0.9333, Test Acc: 0.8421
# Epoch 92: Train Loss: 0.0629, Train Acc: 0.9200, Test Acc: 0.8421
# Epoch 93: Train Loss: 0.2243, Train Acc: 0.9000, Test Acc: 0.8421
# Epoch 94: Train Loss: 0.1729, Train Acc: 0.9400, Test Acc: 0.9474
# Epoch 95: Train Loss: 0.2390, Train Acc: 0.9400, Test Acc: 0.8421
# Epoch 96: Train Loss: 0.2203, Train Acc: 0.9400, Test Acc: 0.9474
# Epoch 97: Train Loss: 0.1071, Train Acc: 0.9333, Test Acc: 0.8421
# Epoch 98: Train Loss: 0.3381, Train Acc: 0.9467, Test Acc: 0.9474
# Epoch 99: Train Loss: 0.1811, Train Acc: 0.9400, Test Acc: 0.8947
# Epoch 100: Train Loss: 0.3951, Train Acc: 0.9533, Test Acc: 0.8947
Train Acc: 0.9867, Test Acc: 0.8947
# Epoch 344: Train Loss: 0.0785, Train Acc: 0.9867, Test Acc: 0.8947
# Epoch 345: Train Loss: 0.0932, Train Acc: 0.9867, Test Acc: 0.8947
# Epoch 346: Train Loss: 0.0544, Train Acc: 0.9933, Test Acc: 0.8421
# Epoch 347: Train Loss: 0.0542, Train Acc: 0.9800, Test Acc: 0.8947
# Epoch 348: Train Loss: 0.1648, Train Acc: 0.9867, Test Acc: 0.8947
# Epoch 349: Train Loss: 0.1885, Train Acc: 0.9800, Test Acc: 0.9474
# Epoch 350: Train Loss: 0.0141, Train Acc: 0.9800, Test Acc: 0.8421
# Epoch 351: Train Loss: 0.1347, Train Acc: 0.9867, Test Acc: 0.8421
# Epoch 352: Train Loss: 0.2144, Train Acc: 0.9533, Test Acc: 0.9474
# Epoch 353: Train Loss: 0.0346, Train Acc: 0.9733, Test Acc: 0.8421
# Epoch 354: Train Loss: 0.0200, Train Acc: 0.9733, Test Acc: 0.8421
# Epoch 355: Train Loss: 0.0295, Train Acc: 0.9933, Test Acc: 0.8947
# Epoch 356: Train Loss: 0.0166, Train Acc: 0.9867, Test Acc: 0.9474
# Epoch 357: Train Loss: 0.0280, Train Acc: 0.9933, Test Acc: 0.8947
# Epoch 358: Train Loss: 0.0137, Train Acc: 0.9867, Test Acc: 0.8947
# Epoch 359: Train Loss: 0.0230, Train Acc: 0.9867, Test Acc: 0.7895
# Epoch 360: Train Loss: 0.0634, Train Acc: 0.9933, Test Acc: 0.7895
# Epoch 361: Train Loss: 0.0310, Train Acc: 0.9933, Test Acc: 0.8421
# Epoch 362: Train Loss: 0.0061, Train Acc: 0.9933, Test Acc: 0.8947
# Epoch 363: Train Loss: 0.0601, Train Acc: 0.9867, Test Acc: 0.7895
# Epoch 364: Train Loss: 0.1642, Train Acc: 0.9867, Test Acc: 0.7895
# Epoch 365: Train Loss: 0.0009, Train Acc: 0.9733, Test Acc: 0.7895
# Epoch 366: Train Loss: 0.0719, Train Acc: 1.0000, Test Acc: 0.8421
# Epoch 367: Train Loss: 0.3292, Train Acc: 0.9800, Test Acc: 0.8421
# Epoch 368: Train Loss: 0.0786, Train Acc: 0.9800, Test Acc: 0.8421
# Epoch 369: Train Loss: 0.0771, Train Acc: 0.9733, Test Acc: 0.8947
# Epoch 370: Train Loss: 0.0688, Train Acc: 0.9733, Test Acc: 0.9474
# Epoch 371: Train Loss: 0.0015, Train Acc: 0.9933, Test Acc: 0.8947
# Epoch 372: Train Loss: 0.0595, Train Acc: 0.9800, Test Acc: 0.8421
# Epoch 373: Train Loss: 0.1367, Train Acc: 0.9867, Test Acc: 0.8421
# Epoch 374: Train Loss: 0.0474, Train Acc: 0.9867, Test Acc: 0.8947
# Epoch 375: Train Loss: 0.0016, Train Acc: 0.9867, Test Acc: 0.8421
# Epoch 376: Train Loss: 0.0620, Train Acc: 0.9800, Test Acc: 0.8421
# Epoch 377: Train Loss: 0.0925, Train Acc: 0.9867, Test Acc: 0.8421
# Epoch 378: Train Loss: 0.0543, Train Acc: 0.9933, Test Acc: 0.8947
# Epoch 379: Train Loss: 0.0322, Train Acc: 0.9933, Test Acc: 0.8947
# Epoch 380: Train Loss: 0.1601, Train Acc: 0.9933, Test Acc: 0.8947
# Epoch 381: Train Loss: 0.0240, Train Acc: 0.9933, Test Acc: 0.8421
# Epoch 382: Train Loss: 0.0525, Train Acc: 1.0000, Test Acc: 0.8947
# Epoch 383: Train Loss: 0.0330, Train Acc: 0.9867, Test Acc: 0.8947
# Epoch 384: Train Loss: 0.0131, Train Acc: 0.9933, Test Acc: 0.8947
# Epoch 385: Train Loss: 0.0435, Train Acc: 1.0000, Test Acc: 0.8421
# Epoch 386: Train Loss: 0.0590, Train Acc: 1.0000, Test Acc: 0.8947
# Epoch 387: Train Loss: 0.0403, Train Acc: 0.9867, Test Acc: 0.8947
# Epoch 388: Train Loss: 0.1016, Train Acc: 0.9867, Test Acc: 0.8947
# Epoch 389: Train Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.8947
# Epoch 390: Train Loss: 0.0059, Train Acc: 1.0000, Test Acc: 0.9474
# Epoch 391: Train Loss: 0.0349, Train Acc: 1.0000, Test Acc: 0.9474
# Epoch 392: Train Loss: 0.0100, Train Acc: 1.0000, Test Acc: 0.9474
# Epoch 393: Train Loss: 0.0076, Train Acc: 1.0000, Test Acc: 0.9474
# Epoch 394: Train Loss: 0.0023, Train Acc: 1.0000, Test Acc: 0.8947
# Epoch 395: Train Loss: 0.0325, Train Acc: 1.0000, Test Acc: 0.8947
# Epoch 396: Train Loss: 0.0345, Train Acc: 0.9933, Test Acc: 0.9474
# Epoch 397: Train Loss: 0.0030, Train Acc: 1.0000, Test Acc: 0.8947
# Epoch 398: Train Loss: 0.0040, Train Acc: 1.0000, Test Acc: 0.8947
# Epoch 399: Train Loss: 0.0058, Train Acc: 1.0000, Test Acc: 0.8947
# Epoch 400: Train Loss: 0.0005, Train Acc: 1.0000, Test Acc: 0.8947
# Epoch 401: Train Loss: 0.0440, Train Acc: 1.0000, Test Acc: 0.8947
# Epoch 402: Train Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.8947
# Epoch 403: Train Loss: 0.0020, Train Acc: 0.9933, Test Acc: 0.8947
# Epoch 404: Train Loss: 0.0137, Train Acc: 0.9933, Test Acc: 0.8947
# Epoch 405: Train Loss: 0.1072, Train Acc: 1.0000, Test Acc: 0.8421
# Epoch 406: Train Loss: 1.1821, Train Acc: 0.9600, Test Acc: 0.7895
# Epoch 407: Train Loss: 0.6101, Train Acc: 0.9467, Test Acc: 0.8421
# Epoch 408: Train Loss: 0.0485, Train Acc: 0.9533, Test Acc: 0.7895
# Epoch 409: Train Loss: 0.0281, Train Acc: 0.9667, Test Acc: 0.8421
# Epoch 410: Train Loss: 0.3278, Train Acc: 0.9733, Test Acc: 0.8947
# Epoch 411: Train Loss: 0.1994, Train Acc: 0.9800, Test Acc: 0.8421
# Epoch 412: Train Loss: 0.0534, Train Acc: 0.9733, Test Acc: 0.8947
# Epoch 413: Train Loss: 0.1281, Train Acc: 0.9733, Test Acc: 0.8421
# Epoch 414: Train Loss: 0.0335, Train Acc: 0.9800, Test Acc: 0.8947
# Epoch 415: Train Loss: 0.0555, Train Acc: 0.9600, Test Acc: 0.8947
# Epoch 416: Train Loss: 0.0241, Train Acc: 0.9800, Test Acc: 0.8421
# Epoch 417: Train Loss: 0.0463, Train Acc: 0.9867, Test Acc: 0.8421
# Epoch 418: Train Loss: 0.0809, Train Acc: 0.9733, Test Acc: 0.8421
# Epoch 419: Train Loss: 0.0644, Train Acc: 0.9867, Test Acc: 0.8421
# Epoch 420: Train Loss: 0.0243, Train Acc: 0.9933, Test Acc: 0.8421
# Epoch 421: Train Loss: 0.0447, Train Acc: 0.9933, Test Acc: 0.8421
# Epoch 422: Train Loss: 0.0368, Train Acc: 0.9933, Test Acc: 0.8947
# Epoch 423: Train Loss: 0.0558, Train Acc: 0.9933, Test Acc: 0.8947
# Epoch 424: Train Loss: 0.0340, Train Acc: 0.9933, Test Acc: 0.8947
# Epoch 425: Train Loss: 0.0222, Train Acc: 1.0000, Test Acc: 0.8947
# Epoch 426: Train Loss: 0.0376, Train Acc: 1.0000, Test Acc: 0.8421
# Epoch 427: Train Loss: 0.0400, Train Acc: 1.0000, Test Acc: 0.8421
# Epoch 428: Train Loss: 0.0208, Train Acc: 0.9867, Test Acc: 0.8947
# Epoch 429: Train Loss: 0.0054, Train Acc: 1.0000, Test Acc: 0.8421
# Epoch 430: Train Loss: 0.0256, Train Acc: 0.9733, Test Acc: 0.8421
# Epoch 431: Train Loss: 0.0196, Train Acc: 0.9867, Test Acc: 0.8947
# Epoch 432: Train Loss: 0.0385, Train Acc: 0.9933, Test Acc: 0.8947
# Epoch 433: Train Loss: 0.0134, Train Acc: 0.9933, Test Acc: 0.8421
# Epoch 434: Train Loss: 0.0036, Train Acc: 0.9933, Test Acc: 0.8421
# Epoch 435: Train Loss: 0.0166, Train Acc: 0.9933, Test Acc: 0.8947
# Epoch 436: Train Loss: 0.0077, Train Acc: 1.0000, Test Acc: 0.8421
# Epoch 437: Train Loss: 0.0072, Train Acc: 1.0000, Test Acc: 0.8421
# Epoch 438: Train Loss: 0.0256, Train Acc: 1.0000, Test Acc: 0.8421
# Epoch 439: Train Loss: 0.0101, Train Acc: 1.0000, Test Acc: 0.8947
# Epoch 440: Train Loss: 0.0424, Train Acc: 1.0000, Test Acc: 0.8421
# Epoch 441: Train Loss: 0.0035, Train Acc: 0.9933, Test Acc: 0.8421
# Epoch 442: Train Loss: 0.0265, Train Acc: 0.9867, Test Acc: 0.7895
# Epoch 443: Train Loss: 0.0382, Train Acc: 0.9800, Test Acc: 0.8947
# Epoch 444: Train Loss: 0.3074, Train Acc: 0.9867, Test Acc: 0.8947
# Epoch 445: Train Loss: 0.0728, Train Acc: 0.9733, Test Acc: 0.6842
# Epoch 446: Train Loss: 0.0773, Train Acc: 0.9733, Test Acc: 0.7895
# Epoch 447: Train Loss: 0.0232, Train Acc: 0.9867, Test Acc: 0.8947
# Epoch 448: Train Loss: 0.1292, Train Acc: 0.9800, Test Acc: 0.9474
# Epoch 449: Train Loss: 0.1042, Train Acc: 0.9867, Test Acc: 0.9474
# Epoch 450: Train Loss: 0.0370, Train Acc: 0.9933, Test Acc: 0.7895
# Epoch 451: Train Loss: 0.1156, Train Acc: 0.9933, Test Acc: 0.8421
# Epoch 452: Train Loss: 0.0231, Train Acc: 0.9867, Test Acc: 0.8947
# Epoch 453: Train Loss: 0.1078, Train Acc: 0.9933, Test Acc: 0.8947
# Epoch 454: Train Loss: 0.0241, Train Acc: 0.9933, Test Acc: 0.7895
# Epoch 455: Train Loss: 0.0107, Train Acc: 1.0000, Test Acc: 0.7895
# Epoch 456: Train Loss: 0.0021, Train Acc: 0.9867, Test Acc: 0.8421
# Epoch 457: Train Loss: 0.0001, Train Acc: 1.0000, Test Acc: 0.8421
# Epoch 458: Train Loss: 0.0240, Train Acc: 1.0000, Test Acc: 0.8421
# Epoch 459: Train Loss: 0.0383, Train Acc: 1.0000, Test Acc: 0.8421
# Epoch 460: Train Loss: 0.0130, Train Acc: 1.0000, Test Acc: 0.8421
# Epoch 461: Train Loss: 0.0202, Train Acc: 1.0000, Test Acc: 0.7895
# Epoch 462: Train Loss: 0.0011, Train Acc: 1.0000, Test Acc: 0.7895
# Epoch 463: Train Loss: 0.0134, Train Acc: 1.0000, Test Acc: 0.8421
# Epoch 464: Train Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.8421
# Epoch 465: Train Loss: 0.0145, Train Acc: 1.0000, Test Acc: 0.7895
# Epoch 466: Train Loss: 0.0414, Train Acc: 1.0000, Test Acc: 0.7895
# Epoch 467: Train Loss: 0.0575, Train Acc: 1.0000, Test Acc: 0.7895
# Epoch 468: Train Loss: 0.0006, Train Acc: 1.0000, Test Acc: 0.8947
# Epoch 469: Train Loss: 0.0228, Train Acc: 1.0000, Test Acc: 0.8947
# Epoch 470: Train Loss: 0.0013, Train Acc: 1.0000, Test Acc: 0.8421
# Epoch 471: Train Loss: 0.0475, Train Acc: 1.0000, Test Acc: 0.8421
# Epoch 472: Train Loss: 0.0092, Train Acc: 0.9933, Test Acc: 0.8947
# Epoch 473: Train Loss: 0.0007, Train Acc: 1.0000, Test Acc: 0.8947
# Epoch 474: Train Loss: 0.1227, Train Acc: 1.0000, Test Acc: 0.8947
# Epoch 475: Train Loss: 0.0095, Train Acc: 0.9867, Test Acc: 0.8947
# Epoch 476: Train Loss: 0.0571, Train Acc: 0.9933, Test Acc: 0.8421
# Epoch 477: Train Loss: 0.0029, Train Acc: 1.0000, Test Acc: 0.8421
# Epoch 478: Train Loss: 0.0340, Train Acc: 1.0000, Test Acc: 0.8947
# Epoch 479: Train Loss: 0.0132, Train Acc: 1.0000, Test Acc: 0.8947
# Epoch 480: Train Loss: 0.0017, Train Acc: 0.9933, Test Acc: 0.7895
# Epoch 481: Train Loss: 0.0297, Train Acc: 1.0000, Test Acc: 0.7895
# Epoch 482: Train Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.8947
# Epoch 483: Train Loss: 0.0116, Train Acc: 1.0000, Test Acc: 0.8947
# Epoch 484: Train Loss: 0.0220, Train Acc: 1.0000, Test Acc: 0.8947
# Epoch 485: Train Loss: 0.0057, Train Acc: 1.0000, Test Acc: 0.7895
# Epoch 486: Train Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.7895
# Epoch 487: Train Loss: 0.0012, Train Acc: 1.0000, Test Acc: 0.8947
# Epoch 488: Train Loss: 0.0007, Train Acc: 1.0000, Test Acc: 0.7895
# Epoch 489: Train Loss: 0.0138, Train Acc: 1.0000, Test Acc: 0.7895
# Epoch 490: Train Loss: 0.0510, Train Acc: 1.0000, Test Acc: 0.8947
# Epoch 491: Train Loss: 0.0011, Train Acc: 1.0000, Test Acc: 0.8947
# Epoch 492: Train Loss: 0.0012, Train Acc: 1.0000, Test Acc: 0.8421
# Epoch 493: Train Loss: 0.0028, Train Acc: 1.0000, Test Acc: 0.8947
# Epoch 494: Train Loss: 0.0164, Train Acc: 0.9933, Test Acc: 0.8947
# Epoch 495: Train Loss: 0.0019, Train Acc: 0.9933, Test Acc: 0.7895
# Epoch 496: Train Loss: 0.0037, Train Acc: 1.0000, Test Acc: 0.9474
# Epoch 497: Train Loss: 0.0100, Train Acc: 0.9933, Test Acc: 0.8947
# Epoch 498: Train Loss: 0.0300, Train Acc: 0.9933, Test Acc: 0.8947
# Epoch 499: Train Loss: 0.0310, Train Acc: 1.0000, Test Acc: 0.8421

# %%
def evaluate_accuracy(loader, model):
    model.eval()
    correct = 0
    total = 0

    with torch.no_grad():
        for data in loader:
            out, embedding = model(data.x, data.edge_index, data.batch)
            pred = out.argmax(dim=1)
            correct += (pred == data.y).sum().item()
            total += data.num_graphs

    return correct / total
train_acc = evaluate_accuracy(train_loader, gcn)
val_acc = evaluate_accuracy(val_loader, gcn)
test_acc = evaluate_accuracy(test_loader, gcn)
print(f"Train Accuracy: {train_acc:.4f}")
print(f"Validation Accuracy: {val_acc:.4f}")
print(f"Test Accuracy: {test_acc:.4f}")
# Out:
# Train Accuracy: 1.0000
# Validation Accuracy: 0.7895
# Test Accuracy: 0.8421

# %%
torch.save(gcn.state_dict(), "../model/GCN_mutag.pth")

# %%
i = 77
pred = gcn.predict(dataset[i].x, dataset[i].edge_index, None)
print(pred[0].argmax(dim=1))
print(dataset[i].y)
# Out:
# tensor([0])
# tensor([0])
